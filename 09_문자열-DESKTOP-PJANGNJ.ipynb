# %%
hello = "Hello World!"
hello
# Out:
# 'Hello World!'

# %%
hello = "안녕하세요"
hello
# Out:
# '안녕하세요'

# %%
hello = '''Hello World'''
hello
# Out:
# 'Hello World'

# %%
python = """Python Programming"""
python
# Out:
# 'Python Programming'

# %%
# 여러줄로 된 문자열 사용하기
hello = '''Hello, World!
안녕하세요
Python입니다.'''

#print(hello)
hello
# Out:
# 'Hello, World!\n안녕하세요\nPython입니다.'

# %%
# 문자열 안에 작은따옴표나 큰 따옴표 포함하기

s = "Python isn't difficult"
s
# Out:
# "Python isn't difficult"

# %%
s = "He \'sa\nid \"Python \tis \\easy\""
print(s)
# Out:
# He 'sa
# id "Python 	is \easy"

# %%
s = """Python is a programming language that lets you work quickly\nand \nintegrate systems more efficitively"""
print (s)
# Out:
# Python is a programming language that lets you work quickly
# and
# integrate systems more efficitively

# %%
s = """"Python is a "programming language \nthat lets you work quichly \nand \ninegrate systems more effectively"""
print(s)
# Out:
# "Python is a "programming language
# that lets you work quichly
# and
# inegrate systems more effectively
