# %%
x = 10
if x == 10:
    pass
    print("x = 10 입니다.")
# Out:
# x = 10 입니다.

# %%
x = 5
if x == 10:
    print("x에 들어있는 숫자는")
    
print("x = 10 입니다.")
# Out:
# x = 10 입니다.

# %%
#중첩 if 조건문 사용하기

#x =15
#x = 10
x = 20
if x >= 10:
    print("10이상입니다.")

    if x == 10:
        print("10입니다.")
    if x == 20:
        print("20입니다.")
# Out:
# 10이상입니다.
# 20입니다.

# %%
x = int(input("숫자를 입력하세요: "))

if x == 10:
    print("10입니다.")
if x ==20:
    print("20입니다.")
# Out:
# 10입니다.

# %%
#13.7 문제

price = 27000
coupon =3000
if price >= 20000:
    print(price - coupon)

price_1 = 72000
coupon_1 = 5000
if price_1 >= 70000:
    print(price_1-coupon_1)
# Out:
# 24000
# 67000
