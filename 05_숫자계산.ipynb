# %%
# 사칙연산

print( 1+1)
# 1-1 ===> print로 출력이 가능하지만 뒤에 아무것도 없으면 바로 계산이 가능함 (하지만 밑에 또 다른 코드나 print가 있다면 출력이 안됨)
print(2*2)
print(4 / 2)
print(4 // 2 )  # 몫 연산자 뒤에 .0을 없애버림 => 즉 몫만 나타냄
# Out:
# 2
# 4
# 2.0
# 2

# %%
# 나눗셈 후ㅡ 소수점 이하를 버리는 // 연산자 (몫)

5//2
# Out:
# 2

# %%
#  % 연산자(나머지를 구하는 연산자)
5 % 2
# Out:
# 1

# %%
#  ** 거듭제곱을 구하는 연산자

2**10
4 ** 0.5
# Out:
# 2.0

# %%
#  값을 정수로 만들기
int (3.3)
int(4 / 2)
#  print를 안쓰고 그냥 작성하면 밑에 있는 값만 출력
# Out:
# 2

# %%
#  객체의 자료형 알아내기(type)
type(10)
# Out:
# int

# %%
#  2진수 
print(0b110)
(1 * 2 ** 2) + (1 * 2 ** 1) + (0 * 2 ** 0)
0b111111
# Out:
# 6
# 63

# %%
#  8진수
print(0o110)
(1 * 8 **2) + (1* 8 ** 1) + (0 * 8 ** 0)
# Out:
# 72
# 72

# %%
#  16진수
print(0xaf)
(10 * 16 ** 1) + (15 * 16 ** 0)
# Out:
# 175
# 175

# %%
#  실수 계산하기
3.5 + 2.1 
4.2 + 5
4.3 - 2.7 () #컴퓨터가 실수를 표현할 때 오차가 발생하기도 한거임
# Out:
# 1.5999999999999996

# %%
#  값을 실수로 만들기

float(5)
float
float("5.3") # 5.3을 숫자가 아닌 문자로 인식함
float("hi") # 실제 문자를 넣으면 에러 발생
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 6
#       2
#       3 float(5)
#       4 float
#       5 float("5.3") # 5.3을 숫자가 아닌 문자로 인식함
# ----> 6 float("hi")
#
# ValueError: could not convert string to float: 'hi'

# %%
#  괄호 사용하기 
print(2 + 2 * 2) 
print((2 + 2) * 2)
# Out:
# 6
# 8
